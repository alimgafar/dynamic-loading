# %% [markdown]
# # Web Scraping Code

# %% [markdown]
# This is the code that will be used for the various python scrapers. Each section will detail out its own scenario-specific code. I expect we'll have specific code for each type of scraper.

# %%
import requests
import json
from time import sleep
import random # to set sleep values

# %% [markdown]
# # Meetup

# %%
sources = ["https://www.meetup.com/ApolloMeteorNYC/events/", "https://www.hellomonday.com/", "https://www.meetup.com/ApolloMeteorNYC/members/"]
mgroups = ["Data-Science-Panel","ApolloMeteorNYC","sfomug","New-York-MongoDB-User-Group"]

all_members = []
group_listing = []

total_members = [1505,2866,3146,6575]
#total_members = [2,1,2,3]


PAGESIZE = 30

# %% [markdown]
# ### Meetup member listings

# %% [markdown]
# A short description here.

# %%
def getOne(member_array):
    
    web_r = requests.get("https://www.meetup.com/mu_api/urlname/members?queries=%28endpoint%3Agroups%2FApolloMeteorNYC%2Fmembers%2Clist%3A%28dynamicRef%3Alist_groupMembers_apollometeornyc_all%2Cmerge%3A%28isReverse%3A%21f%29%29%2Cmeta%3A%28method%3Aget%29%2Cparams%3A%28filter%3Aall%2Cpage%3A1%2Csort%3Ajoined%29%2Cref%3AgroupMembers_apollometeornyc_all%29")
    outer_list = web_r.json().get("responses")
    return outer_list

all_members.append(getOne(all_members))

# %%
len(all_members)
all_members[0]
# Out:
# [{'ref': 'groupMembers_apollometeornyc_all',
#   'value': {'value': [{'id': '200737999',
#      'joined': '2020-04-09T23:38:37.000Z',
#      'name': 'osmanatam',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '255891876',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/c/a/a/4/highres_255891876.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/c/a/a/4/thumb_255891876.jpeg'}},
#     {'id': '281356625',
#      'joined': '2020-04-09T23:29:58.000Z',
#      'name': 'Peter D.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '295420451',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/9/e/0/3/highres_295420451.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/e/0/3/thumb_295420451.jpeg'}},
#     {'id': '1639448',
#      'joined': '2020-04-08T19:48:13.000Z',
#      'name': 'Crispina M.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '292217160',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/4/3/0/8/highres_292217160.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/3/0/8/thumb_292217160.jpeg'}},
#     {'id': '11737990',
#      'joined': '2020-04-02T13:46:19.000Z',
#      'name': 'David W.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '298564420',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/1/1/4/4/highres_298564420.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/1/1/4/4/thumb_298564420.jpeg'}},
#     {'id': '303060454',
#      'joined': '2020-03-23T04:44:47.000Z',
#      'name': 'Chynar M.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': ''},
#     {'id': '294103526',
#      'joined': '2020-03-22T11:06:42.000Z',
#      'name': 'Jude A.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': ''},
#     {'id': '205788447',
#      'joined': '2020-03-20T18:20:48.000Z',
#      'name': 'C L',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '267398953',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/9/8/2/9/highres_267398953.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/8/2/9/thumb_267398953.jpeg'}},
#     {'id': '194477673',
#      'joined': '2020-03-16T19:02:16.000Z',
#      'name': 'Ronald A.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '278440700',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/9/e/f/c/highres_278440700.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/e/f/c/thumb_278440700.jpeg'}},
#     {'id': '194568945',
#      'joined': '2020-03-16T15:28:56.000Z',
#      'name': 'Jesse C.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '286425608',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/b/2/2/8/highres_286425608.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/2/2/8/thumb_286425608.jpeg'}},
#     {'id': '33460632',
#      'joined': '2020-03-06T23:53:34.000Z',
#      'name': 'Ronald E. A.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '255078936',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/4/9/f/8/highres_255078936.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/9/f/8/thumb_255078936.jpeg'}},
#     {'id': '225665634',
#      'joined': '2020-03-06T22:16:02.000Z',
#      'name': 'Tyler K.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '286825963',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/6/5/6/b/highres_286825963.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/6/5/6/b/thumb_286825963.jpeg'}},
#     {'id': '303974943',
#      'joined': '2020-03-06T19:59:06.000Z',
#      'name': 'Hasani',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '298117711',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/9/3/4/f/highres_298117711.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/3/4/f/thumb_298117711.jpeg'}},
#     {'id': '200165839',
#      'joined': '2020-03-04T18:37:09.000Z',
#      'name': 'Aliciea Dawn S.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '254085575',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/b/2/0/7/highres_254085575.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/2/0/7/thumb_254085575.jpeg'}},
#     {'id': '216638532',
#      'joined': '2020-03-04T17:37:21.000Z',
#      'name': 'Jordan W.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '295722301',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/a/5/3/d/highres_295722301.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/5/3/d/thumb_295722301.jpeg'}},
#     {'id': '83813632',
#      'joined': '2020-03-04T17:17:01.000Z',
#      'name': 'Daniel W.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '147511862',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/7/c/7/6/highres_147511862.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/c/7/6/thumb_147511862.jpeg'}},
#     {'id': '197285351',
#      'joined': '2020-03-04T14:08:56.000Z',
#      'name': 'Roy M',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '287481217',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/5/2/e/1/highres_287481217.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/5/2/e/1/thumb_287481217.jpeg'}},
#     {'id': '276619295',
#      'joined': '2020-03-04T06:00:46.000Z',
#      'name': 'Amritpal S.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '294707743',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/b/a/7/f/highres_294707743.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/a/7/f/thumb_294707743.jpeg'}},
#     {'id': '204312330',
#      'joined': '2020-03-03T17:42:38.000Z',
#      'name': 'Cihat',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '270457450',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/9/2/4/a/highres_270457450.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/2/4/a/thumb_270457450.jpeg'}},
#     {'id': '301349119',
#      'joined': '2020-03-03T14:32:08.000Z',
#      'name': 'Joshua A.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '296851869',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/7/c/7/d/highres_296851869.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/c/7/d/thumb_296851869.jpeg'}},
#     {'id': '283918150',
#      'joined': '2020-02-29T19:53:40.000Z',
#      'name': 'Matt D.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '293524013',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/f/a/d/highres_293524013.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/f/a/d/thumb_293524013.jpeg'}},
#     {'id': '278923851',
#      'joined': '2020-02-27T18:43:24.000Z',
#      'name': 'Olesia G.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '295379323',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/e/7/b/b/highres_295379323.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/e/7/b/b/thumb_295379323.jpeg'}},
#     {'id': '192862616',
#      'joined': '2020-02-27T06:25:30.000Z',
#      'name': 'Alex N.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '283732914',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/c/e/b/2/highres_283732914.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/c/e/b/2/thumb_283732914.jpeg'}},
#     {'id': '196345795',
#      'joined': '2020-02-25T11:10:11.000Z',
#      'name': 'Jonathan M.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '251828524',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/2/1/4/c/highres_251828524.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/2/1/4/c/thumb_251828524.jpeg'}},
#     {'id': '297592490',
#      'joined': '2020-02-24T22:47:09.000Z',
#      'name': 'Khaled',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '295082829',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/b/0/d/highres_295082829.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/0/d/thumb_295082829.jpeg'}},
#     {'id': '301437697',
#      'joined': '2020-02-24T15:56:36.000Z',
#      'name': 'Grace',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': ''},
#     {'id': '286242401',
#      'joined': '2020-02-24T02:54:04.000Z',
#      'name': 'Stephanie L.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '292087034',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/1/b/7/a/highres_292087034.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/1/b/7/a/thumb_292087034.jpeg'}},
#     {'id': '43363972',
#      'joined': '2020-02-19T04:17:12.000Z',
#      'name': 'Wilson J.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '278821154',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/4/8/2/highres_278821154.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/8/2/thumb_278821154.jpeg'}},
#     {'id': '288694128',
#      'joined': '2020-02-18T17:31:39.000Z',
#      'name': 'Jasper',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '291914788',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/3/9/c/4/highres_291914788.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/9/c/4/thumb_291914788.jpeg'}},
#     {'id': '296419437',
#      'joined': '2020-02-18T15:35:33.000Z',
#      'name': 'Joel L.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '294648669',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/b/e/1/d/highres_294648669.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/e/1/d/thumb_294648669.jpeg'}},
#     {'id': '302837544',
#      'joined': '2020-02-18T13:27:54.000Z',
#      'name': 'Brett J.',
#      'role': '',
#      'status': 'active',
#      'intro': '',
#      'title': '',
#      'photo': {'id': '297569776',
#       'highres_link': 'https://secure.meetupstatic.com/photos/member/7/4/5/0/highres_297569776.jpeg',
#       'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/4/5/0/thumb_297569776.jpeg'}}]},
#   'meta': {'endpoint': 'groups/ApolloMeteorNYC/members', 'statusCode': 200}}]

# %%
# requires a match pattern and a meetup name.

# page_grabs calculates the number of calls required to the XHR URL to get all members.

def page_grabs(total_members):
    total_pages = total_members//PAGESIZE
    if total_members%PAGESIZE > 0:
        total_pages = total_pages + 1
    print(f"Making {total_pages} fetches\n")
    return total_pages

def makeXhrUrl(meetup_group, page):
    source_url = "https://www.meetup.com/mu_api/urlname/members?queries=%28endpoint%3Agroups%2F{meetup_group}%2Fmembers%2Clist%3A%28dynamicRef%3Alist_groupMembers_{meetup_group_lc}_all%2Cmerge%3A%28isReverse%3A%21f%29%29%2Cmeta%3A%28method%3Aget%29%2Cparams%3A%28filter%3Aall%2Cpage%3A{page}%2Csort%3Ajoined%29%2Cref%3AgroupMembers_{meetup_group_lc}_all%29".format(meetup_group=meetup_group, page=page, meetup_group_lc=meetup_group.lower())
    #print("Assemble the URL and inject the appropriate parameters; start on the first page")
    return source_url
    

def download_listing(meetup_group, total_members):
    filename = "data/{group}.json".format(group=meetup_group)
    total_pages = page_grabs(total_members)
    try:
        with open("{fn}".format(fn=filename),"a") as outfile:
            for page in range(total_pages):
                web_req = requests.get(makeXhrUrl(meetup_group, page))
                all_members.append(web_req.json().get("responses"))

                json.dump(all_members, outfile)

                duration = random.randint(2, 13)
                sleep(duration)
                print(f"Slept {duration} after fetching {meetup_group} page {page} listing!")
    except:
        print("Encountered a problem writing while iterating.")
        
    print(f"Saved all_members data to {outfile.name}.")        
    return all_members

# %% [markdown]
# ### Meetup classic profile page details

# %% [markdown]
# Make sure to scrape these pages with a logged-in meetup.com account, and you will get the full member names. So use Selenium.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
# some code here
def grabThePage(classic_profile, pattern):
    pass

# %% [markdown]
# ### Meetup new profile page details

# %% [markdown]
# Make sure to scrape these pages with a logged-in meetup.com account, and you will get the full member names. So use Selenium.

# %%
# some code here too

# %% [markdown]
# ## Test drivers

# %% [markdown]
# The code below will be used to thest the functions written above. They also include test data

# %%
for i, mgroup in enumerate(mgroups):
    print(i, mgroup, total_members[i], page_grabs(total_members[i]))
# Out:
# Making 51 fetches
#
# 0 Data-Science-Panel 1505 51
# Making 96 fetches
#
# 1 ApolloMeteorNYC 2866 96
# Making 105 fetches
#
# 2 sfomug 3146 105
# Making 220 fetches
#
# 3 New-York-MongoDB-User-Group 6575 220

# %%
page_grabs(total_members[1])
# Out:
# Making 96 fetches
# 96

# %%
duration = random.randint(2, 13)
sleep(duration)
print(f"Slept {duration}!")
# Out:
# Slept 4!

# %%
# makeXhrUrl(mgroups[0],1)
all_members = []

for i, mgroup in enumerate(mgroups):
    download_listing(mgroup,total_members[i])
# Out:
# Making 51 fetches
#
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 13 after fetching Data-Science-Panel page 0 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 12 after fetching Data-Science-Panel page 1 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 7 after fetching Data-Science-Panel page 2 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 6 after fetching Data-Science-Panel page 3 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 9 after fetching Data-Science-Panel page 4 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 13 after fetching Data-Science-Panel page 5 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 11 after fetching Data-Science-Panel page 6 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 6 after fetching Data-Science-Panel page 7 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 8 after fetching Data-Science-Panel page 8 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 9 after fetching Data-Science-Panel page 9 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 8 after fetching Data-Science-Panel page 10 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 6 after fetching Data-Science-Panel page 11 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 12 after fetching Data-Science-Panel page 12 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 6 after fetching Data-Science-Panel page 13 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 8 after fetching Data-Science-Panel page 14 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 13 after fetching Data-Science-Panel page 15 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 11 after fetching Data-Science-Panel page 16 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 9 after fetching Data-Science-Panel page 17 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 7 after fetching Data-Science-Panel page 18 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 2 after fetching Data-Science-Panel page 19 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 4 after fetching Data-Science-Panel page 20 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 7 after fetching Data-Science-Panel page 21 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 4 after fetching Data-Science-Panel page 22 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 13 after fetching Data-Science-Panel page 23 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 12 after fetching Data-Science-Panel page 24 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 9 after fetching Data-Science-Panel page 25 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 10 after fetching Data-Science-Panel page 26 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 9 after fetching Data-Science-Panel page 27 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 2 after fetching Data-Science-Panel page 28 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 11 after fetching Data-Science-Panel page 29 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 9 after fetching Data-Science-Panel page 30 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 11 after fetching Data-Science-Panel page 31 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 8 after fetching Data-Science-Panel page 32 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 13 after fetching Data-Science-Panel page 33 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 12 after fetching Data-Science-Panel page 34 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 11 after fetching Data-Science-Panel page 35 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 4 after fetching Data-Science-Panel page 36 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 12 after fetching Data-Science-Panel page 37 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 9 after fetching Data-Science-Panel page 38 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 11 after fetching Data-Science-Panel page 39 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 5 after fetching Data-Science-Panel page 40 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 3 after fetching Data-Science-Panel page 41 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 3 after fetching Data-Science-Panel page 42 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 2 after fetching Data-Science-Panel page 43 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 8 after fetching Data-Science-Panel page 44 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 11 after fetching Data-Science-Panel page 45 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 12 after fetching Data-Science-Panel page 46 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 10 after fetching Data-Science-Panel page 47 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 9 after fetching Data-Science-Panel page 48 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 4 after fetching Data-Science-Panel page 49 listing!
# Saved all_members data to data/Data-Science-Panel.json.
# Slept 7 after fetching Data-Science-Panel page 50 listing!
# Making 96 fetches
#
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 0 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 1 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 2 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 3 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 7 after fetching ApolloMeteorNYC page 4 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 5 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 3 after fetching ApolloMeteorNYC page 6 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 7 after fetching ApolloMeteorNYC page 7 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 10 after fetching ApolloMeteorNYC page 8 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 9 after fetching ApolloMeteorNYC page 9 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 4 after fetching ApolloMeteorNYC page 10 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 9 after fetching ApolloMeteorNYC page 11 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 12 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 3 after fetching ApolloMeteorNYC page 13 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 14 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 3 after fetching ApolloMeteorNYC page 15 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 16 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 5 after fetching ApolloMeteorNYC page 17 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 8 after fetching ApolloMeteorNYC page 18 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 10 after fetching ApolloMeteorNYC page 19 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 20 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 21 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 22 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 23 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 5 after fetching ApolloMeteorNYC page 24 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 3 after fetching ApolloMeteorNYC page 25 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 8 after fetching ApolloMeteorNYC page 26 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 4 after fetching ApolloMeteorNYC page 27 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 8 after fetching ApolloMeteorNYC page 28 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 29 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 8 after fetching ApolloMeteorNYC page 30 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 10 after fetching ApolloMeteorNYC page 31 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 32 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 10 after fetching ApolloMeteorNYC page 33 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 34 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 4 after fetching ApolloMeteorNYC page 35 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 36 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 4 after fetching ApolloMeteorNYC page 37 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 5 after fetching ApolloMeteorNYC page 38 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 9 after fetching ApolloMeteorNYC page 39 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 40 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 5 after fetching ApolloMeteorNYC page 41 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 3 after fetching ApolloMeteorNYC page 42 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 43 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 44 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 45 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 8 after fetching ApolloMeteorNYC page 46 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 47 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 48 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 7 after fetching ApolloMeteorNYC page 49 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 50 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 4 after fetching ApolloMeteorNYC page 51 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 13 after fetching ApolloMeteorNYC page 52 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 2 after fetching ApolloMeteorNYC page 53 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 4 after fetching ApolloMeteorNYC page 54 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 9 after fetching ApolloMeteorNYC page 55 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 56 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 2 after fetching ApolloMeteorNYC page 57 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 7 after fetching ApolloMeteorNYC page 58 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 13 after fetching ApolloMeteorNYC page 59 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 9 after fetching ApolloMeteorNYC page 60 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 10 after fetching ApolloMeteorNYC page 61 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 8 after fetching ApolloMeteorNYC page 62 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 7 after fetching ApolloMeteorNYC page 63 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 2 after fetching ApolloMeteorNYC page 64 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 2 after fetching ApolloMeteorNYC page 65 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 8 after fetching ApolloMeteorNYC page 66 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 8 after fetching ApolloMeteorNYC page 67 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 68 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 10 after fetching ApolloMeteorNYC page 69 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 70 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 5 after fetching ApolloMeteorNYC page 71 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 72 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 73 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 13 after fetching ApolloMeteorNYC page 74 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 75 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 7 after fetching ApolloMeteorNYC page 76 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 12 after fetching ApolloMeteorNYC page 77 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 78 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 8 after fetching ApolloMeteorNYC page 79 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 2 after fetching ApolloMeteorNYC page 80 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 7 after fetching ApolloMeteorNYC page 81 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 5 after fetching ApolloMeteorNYC page 82 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 83 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 3 after fetching ApolloMeteorNYC page 84 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 4 after fetching ApolloMeteorNYC page 85 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 5 after fetching ApolloMeteorNYC page 86 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 9 after fetching ApolloMeteorNYC page 87 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 7 after fetching ApolloMeteorNYC page 88 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 89 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 10 after fetching ApolloMeteorNYC page 90 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 6 after fetching ApolloMeteorNYC page 91 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 7 after fetching ApolloMeteorNYC page 92 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 2 after fetching ApolloMeteorNYC page 93 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 11 after fetching ApolloMeteorNYC page 94 listing!
# Saved all_members data to data/ApolloMeteorNYC.json.
# Slept 10 after fetching ApolloMeteorNYC page 95 listing!
# Making 105 fetches
# Saved all_members data to data/sfomug.json.
# Slept 3 after fetching sfomug page 0 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 1 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 2 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 3 listing!
# Saved all_members data to data/sfomug.json.
# Slept 11 after fetching sfomug page 4 listing!
# Saved all_members data to data/sfomug.json.
# Slept 4 after fetching sfomug page 5 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 6 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 7 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 8 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 9 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 10 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 11 listing!
# Saved all_members data to data/sfomug.json.
# Slept 2 after fetching sfomug page 12 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 13 listing!
# Saved all_members data to data/sfomug.json.
# Slept 4 after fetching sfomug page 14 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 15 listing!
# Saved all_members data to data/sfomug.json.
# Slept 11 after fetching sfomug page 16 listing!
# Saved all_members data to data/sfomug.json.
# Slept 3 after fetching sfomug page 17 listing!
# Saved all_members data to data/sfomug.json.
# Slept 6 after fetching sfomug page 18 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 19 listing!
# Saved all_members data to data/sfomug.json.
# Slept 2 after fetching sfomug page 20 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 21 listing!
# Saved all_members data to data/sfomug.json.
# Slept 5 after fetching sfomug page 22 listing!
# Saved all_members data to data/sfomug.json.
# Slept 2 after fetching sfomug page 23 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 24 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 25 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 26 listing!
# Saved all_members data to data/sfomug.json.
# Slept 8 after fetching sfomug page 27 listing!
# Saved all_members data to data/sfomug.json.
# Slept 13 after fetching sfomug page 28 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 29 listing!
# Saved all_members data to data/sfomug.json.
# Slept 3 after fetching sfomug page 30 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 31 listing!
# Saved all_members data to data/sfomug.json.
# Slept 2 after fetching sfomug page 32 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 33 listing!
# Saved all_members data to data/sfomug.json.
# Slept 5 after fetching sfomug page 34 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 35 listing!
# Saved all_members data to data/sfomug.json.
# Slept 13 after fetching sfomug page 36 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 37 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 38 listing!
# Saved all_members data to data/sfomug.json.
# Slept 6 after fetching sfomug page 39 listing!
# Saved all_members data to data/sfomug.json.
# Slept 8 after fetching sfomug page 40 listing!
# Saved all_members data to data/sfomug.json.
# Slept 6 after fetching sfomug page 41 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 42 listing!
# Saved all_members data to data/sfomug.json.
# Slept 3 after fetching sfomug page 43 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 44 listing!
# Saved all_members data to data/sfomug.json.
# Slept 2 after fetching sfomug page 45 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 46 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 47 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 48 listing!
# Saved all_members data to data/sfomug.json.
# Slept 8 after fetching sfomug page 49 listing!
# Saved all_members data to data/sfomug.json.
# Slept 13 after fetching sfomug page 50 listing!
# Saved all_members data to data/sfomug.json.
# Slept 2 after fetching sfomug page 51 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 52 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 53 listing!
# Saved all_members data to data/sfomug.json.
# Slept 11 after fetching sfomug page 54 listing!
# Saved all_members data to data/sfomug.json.
# Slept 3 after fetching sfomug page 55 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 56 listing!
# Saved all_members data to data/sfomug.json.
# Slept 11 after fetching sfomug page 57 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 58 listing!
# Saved all_members data to data/sfomug.json.
# Slept 4 after fetching sfomug page 59 listing!
# Saved all_members data to data/sfomug.json.
# Slept 8 after fetching sfomug page 60 listing!
# Saved all_members data to data/sfomug.json.
# Slept 6 after fetching sfomug page 61 listing!
# Saved all_members data to data/sfomug.json.
# Slept 4 after fetching sfomug page 62 listing!
# Saved all_members data to data/sfomug.json.
# Slept 11 after fetching sfomug page 63 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 64 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 65 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 66 listing!
# Saved all_members data to data/sfomug.json.
# Slept 3 after fetching sfomug page 67 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 68 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 69 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 70 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 71 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 72 listing!
# Saved all_members data to data/sfomug.json.
# Slept 13 after fetching sfomug page 73 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 74 listing!
# Saved all_members data to data/sfomug.json.
# Slept 2 after fetching sfomug page 75 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 76 listing!
# Saved all_members data to data/sfomug.json.
# Slept 6 after fetching sfomug page 77 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 78 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 79 listing!
# Saved all_members data to data/sfomug.json.
# Slept 2 after fetching sfomug page 80 listing!
# Saved all_members data to data/sfomug.json.
# Slept 3 after fetching sfomug page 81 listing!
# Saved all_members data to data/sfomug.json.
# Slept 13 after fetching sfomug page 82 listing!
# Saved all_members data to data/sfomug.json.
# Slept 6 after fetching sfomug page 83 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 84 listing!
# Saved all_members data to data/sfomug.json.
# Slept 3 after fetching sfomug page 85 listing!
# Saved all_members data to data/sfomug.json.
# Slept 8 after fetching sfomug page 86 listing!
# Saved all_members data to data/sfomug.json.
# Slept 5 after fetching sfomug page 87 listing!
# Saved all_members data to data/sfomug.json.
# Slept 5 after fetching sfomug page 88 listing!
# Saved all_members data to data/sfomug.json.
# Slept 4 after fetching sfomug page 89 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 90 listing!
# Saved all_members data to data/sfomug.json.
# Slept 5 after fetching sfomug page 91 listing!
# Saved all_members data to data/sfomug.json.
# Slept 11 after fetching sfomug page 92 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 93 listing!
# Saved all_members data to data/sfomug.json.
# Slept 3 after fetching sfomug page 94 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 95 listing!
# Saved all_members data to data/sfomug.json.
# Slept 11 after fetching sfomug page 96 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 97 listing!
# Saved all_members data to data/sfomug.json.
# Slept 9 after fetching sfomug page 98 listing!
# Saved all_members data to data/sfomug.json.
# Slept 10 after fetching sfomug page 99 listing!
# Saved all_members data to data/sfomug.json.
# Slept 7 after fetching sfomug page 100 listing!
# Saved all_members data to data/sfomug.json.
# Slept 6 after fetching sfomug page 101 listing!
# Saved all_members data to data/sfomug.json.
# Slept 6 after fetching sfomug page 102 listing!
# Saved all_members data to data/sfomug.json.
# Slept 12 after fetching sfomug page 103 listing!
# Saved all_members data to data/sfomug.json.
# Slept 3 after fetching sfomug page 104 listing!
# Making 220 fetches
#
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 0 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 1 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 2 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 3 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 4 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 5 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 6 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 7 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 8 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 9 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 10 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 11 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 12 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 13 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 14 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 15 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 16 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 17 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 18 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 19 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 20 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 21 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 22 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 23 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 24 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 25 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 26 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 27 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 28 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 29 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 30 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 31 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 32 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 33 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 34 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 35 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 36 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 37 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 38 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 39 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 40 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 41 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 42 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 43 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 44 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 45 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 46 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 47 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 48 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 49 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 50 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 51 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 52 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 53 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 54 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 55 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 56 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 57 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 58 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 59 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 60 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 61 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 62 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 63 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 64 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 65 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 66 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 67 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 68 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 69 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 70 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 71 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 72 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 73 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 74 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 75 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 76 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 77 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 78 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 79 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 80 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 81 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 82 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 83 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 84 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 85 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 86 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 87 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 88 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 89 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 90 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 91 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 92 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 93 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 94 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 95 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 96 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 97 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 98 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 99 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 100 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 101 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 102 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 103 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 104 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 105 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 106 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 107 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 108 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 109 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 110 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 111 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 112 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 113 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 114 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 115 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 116 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 117 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 118 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 119 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 120 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 121 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 122 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 123 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 124 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 125 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 126 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 127 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 128 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 129 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 130 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 131 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 132 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 133 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 134 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 135 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 136 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 137 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 138 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 139 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 140 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 141 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 142 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 143 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 144 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 145 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 146 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 147 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 148 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 149 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 150 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 151 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 152 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 153 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 154 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 155 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 156 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 157 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 158 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 159 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 160 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 161 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 162 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 163 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 164 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 165 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 166 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 167 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 168 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 169 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 170 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 171 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 172 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 173 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 174 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 175 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 176 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 177 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 178 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 179 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 180 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 181 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 182 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 183 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 8 after fetching New-York-MongoDB-User-Group page 184 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 185 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 4 after fetching New-York-MongoDB-User-Group page 186 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 187 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 188 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 189 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 190 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 191 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 192 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 193 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 194 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 195 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 2 after fetching New-York-MongoDB-User-Group page 196 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 197 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 198 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 6 after fetching New-York-MongoDB-User-Group page 199 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 200 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 201 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 9 after fetching New-York-MongoDB-User-Group page 202 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 203 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 204 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 205 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 206 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 207 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 208 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 209 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 11 after fetching New-York-MongoDB-User-Group page 210 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 211 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 3 after fetching New-York-MongoDB-User-Group page 212 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 213 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 10 after fetching New-York-MongoDB-User-Group page 214 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 13 after fetching New-York-MongoDB-User-Group page 215 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 216 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 7 after fetching New-York-MongoDB-User-Group page 217 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 5 after fetching New-York-MongoDB-User-Group page 218 listing!
# Saved all_members data to data/New-York-MongoDB-User-Group.json.
# Slept 12 after fetching New-York-MongoDB-User-Group page 219 listing!

# %%
len(all_members)
# Out:
# 472

# %%
with open("data/raw_member_list.json","a") as outfile:
    json.dump(all_members, outfile)
    print(f"Saved all_members data to {outfile.name}.")
# Out:
# Saved all_members data to data/raw_member_list.json.

# %%
for i, mgroup in enumerate(mgroups):
    filename = "data/{group}.array.json".format(group=mgroup)
    try:
        with open("{fn}".format(fn=filename),"a") as outfile:
            for page in range(total_pages):
                json.dump(all_members[page][0].get('value').get('value'), outfile)
                print(f"Saved {mgroup} member data to {outfile.name}. Parse this file to get what you need")        

                duration = random.randint(2, 13)
                sleep(duration)
                print(f"Slept {duration} after fetching {meetup_group} page {page} listing!")
    except:
        print("Encountered a problem writing while iterating.")


ttx = all_members[][0].get('value').get('value')

ttx
#ttx.get('value')
# Out:
#   File "<ipython-input-16-d37a30ccda55>", line 16
#     ttx = all_members[][0].get('value').get('value')
#                       ^
# SyntaxError: invalid syntax
